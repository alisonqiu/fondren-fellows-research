# %%
import pandas as pd

df = pd.read_csv("pulse2022_puf_50.csv")

print(df.describe())
# Out:
#           WEEK        EST_ST       EST_MSA        REGION        HWEIGHT  \
# count  42040.0  42040.000000  11965.000000  42040.000000   42040.000000
# mean      50.0     28.656970  32200.573339      2.711965    2957.788059
# std        0.0     16.265697  11656.568432      1.055910    4592.020407
# min       50.0      1.000000  12060.000000      1.000000      36.115540
# 25%       50.0     15.000000  19100.000000      2.000000     861.655776
# 50%       50.0     28.000000  35620.000000      3.000000    1592.653298
# 75%       50.0     42.000000  41860.000000      4.000000    3228.560118
# max       50.0     56.000000  47900.000000      4.000000  137263.239070
#
#              PWEIGHT   TBIRTH_YEAR   ABIRTH_YEAR     RHISPANIC     AHISPANIC  \
# count   42040.000000  42040.000000  42040.000000  42040.000000  42040.000000
# mean     6005.732897   1969.778425      1.991389      1.084110      1.978306
# std     11173.372827     16.593257      0.092395      0.277557      0.145683
# ...

# %%
df2 = pd.read_csv("pulse2022_repwgt_puf_50.csv")

print(df2.describe())

# %%
dic = pd.read_excel("pulse2022_data.dictionary_CSV_50.xlsx")
dic.head(15)
# Out:
#               Household Pulse Survey   Unnamed: 1      Unnamed: 2  \
# 0   Data Dictionary for CSV - Week50          NaN             NaN
# 1                                NaN          NaN             NaN
# 2                                NaN          NaN             NaN
# 3                     Instrument Q #     Variable     Description
# 4                                 D1  TBIRTH_YEAR     Description
# 5                                NaN          NaN          Values
# 6                                NaN          NaN        Universe
# 7                                NaN          NaN  Internal Notes
# 8                       Recode of D2    RHISPANIC     Description
# 9                                NaN          NaN          Values
# 10                               NaN          NaN        Universe
# 11                               NaN          NaN  Internal Notes
# 12                      Recode of D3        RRACE     Description
# ...

# %%
dic.loc[dic["Unnamed: 1"] == "GAS1"]
# Out:
#     Household Pulse Survey Unnamed: 1   Unnamed: 2   Unnamed: 3  \
# 836                    GAS       GAS1  Description  Cost of gas
#
#                                             Unnamed: 4 Unnamed: 5 Unnamed: 6
# 836  Has the cost of gas in the last 7 days caused ...  <blank>,1        3.6

# %%
#group columns (demographics, socio)
